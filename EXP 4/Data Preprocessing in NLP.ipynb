# %% [markdown]
# # Importing Necessary Packages

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\meets\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\meets\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\meets\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\meets\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# # Define Sample Text

# %%
sample_text = """
A framework for classifying AGI in levels was proposed in 2023 by Google DeepMind researchers. They define five levels of AGI: emerging, competent, expert, virtuoso, and superhuman. For example, a competent AGI is defined as an AI that outperforms 50% of skilled adults in a wide range of non-physical tasks, and a superhuman AGI is similarly defined but with a threshold of 100%. They consider large language models like ChatGPT or LLaMA 2 to be instances of emerging AGI.
"""

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Text Lowercasing

# %%
text = sample_text.lower()
print("Lowercased Text:\n", text)
# Out:
# Lowercased Text:
#
# a framework for classifying agi in levels was proposed in 2023 by google deepmind researchers. they define five levels of agi: emerging, competent, expert, virtuoso, and superhuman. for example, a competent agi is defined as an ai that outperforms 50% of skilled adults in a wide range of non-physical tasks, and a superhuman agi is similarly defined but with a threshold of 100%. they consider large language models like chatgpt or llama 2 to be instances of emerging agi.

# %% [markdown]
# # Removing Punctuation

# %%
text = re.sub(r'[^\w\s]', '', text)
print("Text after Removing Punctuation:\n", text)
# Out:
# Text after Removing Punctuation:
#
# a framework for classifying agi in levels was proposed in 2023 by google deepmind researchers they define five levels of agi emerging competent expert virtuoso and superhuman for example a competent agi is defined as an ai that outperforms 50 of skilled adults in a wide range of nonphysical tasks and a superhuman agi is similarly defined but with a threshold of 100 they consider large language models like chatgpt or llama 2 to be instances of emerging agi

# %% [markdown]
# # Tokenization

# %%
tokens = word_tokenize(text)
print("Tokenized Text:\n", tokens)
# Out:
# Tokenized Text:
#  ['a', 'framework', 'for', 'classifying', 'agi', 'in', 'levels', 'was', 'proposed', 'in', '2023', 'by', 'google', 'deepmind', 'researchers', 'they', 'define', 'five', 'levels', 'of', 'agi', 'emerging', 'competent', 'expert', 'virtuoso', 'and', 'superhuman', 'for', 'example', 'a', 'competent', 'agi', 'is', 'defined', 'as', 'an', 'ai', 'that', 'outperforms', '50', 'of', 'skilled', 'adults', 'in', 'a', 'wide', 'range', 'of', 'nonphysical', 'tasks', 'and', 'a', 'superhuman', 'agi', 'is', 'similarly', 'defined', 'but', 'with', 'a', 'threshold', 'of', '100', 'they', 'consider', 'large', 'language', 'models', 'like', 'chatgpt', 'or', 'llama', '2', 'to', 'be', 'instances', 'of', 'emerging', 'agi']

# %% [markdown]
# # Stopword Removal

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("Text after Stopword Removal:\n", filtered_tokens)
# Out:
# Text after Stopword Removal:
#  ['framework', 'classifying', 'agi', 'levels', 'proposed', '2023', 'google', 'deepmind', 'researchers', 'define', 'five', 'levels', 'agi', 'emerging', 'competent', 'expert', 'virtuoso', 'superhuman', 'example', 'competent', 'agi', 'defined', 'ai', 'outperforms', '50', 'skilled', 'adults', 'wide', 'range', 'nonphysical', 'tasks', 'superhuman', 'agi', 'similarly', 'defined', 'threshold', '100', 'consider', 'large', 'language', 'models', 'like', 'chatgpt', 'llama', '2', 'instances', 'emerging', 'agi']

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("Text after Lemmatization:\n", lemmatized_tokens)
# Out:
# Text after Lemmatization:
#  ['framework', 'classifying', 'agi', 'level', 'proposed', '2023', 'google', 'deepmind', 'researcher', 'define', 'five', 'level', 'agi', 'emerging', 'competent', 'expert', 'virtuoso', 'superhuman', 'example', 'competent', 'agi', 'defined', 'ai', 'outperforms', '50', 'skilled', 'adult', 'wide', 'range', 'nonphysical', 'task', 'superhuman', 'agi', 'similarly', 'defined', 'threshold', '100', 'consider', 'large', 'language', 'model', 'like', 'chatgpt', 'llama', '2', 'instance', 'emerging', 'agi']

# %% [markdown]
# # Consolidating Preprocessing Steps

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    return ' '.join(lemmatized_tokens)

processed_text = preprocess_text(sample_text)
print("Preprocessed Text:\n", processed_text)
# Out:
# Preprocessed Text:
#  framework classifying agi level proposed 2023 google deepmind researcher define five level agi emerging competent expert virtuoso superhuman example competent agi defined ai outperforms 50 skilled adult wide range nonphysical task superhuman agi similarly defined threshold 100 consider large language model like chatgpt llama 2 instance emerging agi
