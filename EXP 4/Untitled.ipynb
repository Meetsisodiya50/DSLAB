# %%
# !pip install nltk

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# Download necessary NLTK data (run only once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\meets\AppData\Local\
# [nltk_data]     Programs\Python\Python312\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\meets\AppData\Lo
# [nltk_data]     cal\Programs\Python\Python312\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\meets\AppData\Loca
# [nltk_data]     l\Programs\Python\Python312\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\meets\AppData\Loca
# [nltk_data]     l\Programs\Python\Python312\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Sample text data
sample_text = """
Natural Language Processing (NLP) is a fascinating field! NLP involves the interaction between computers 
and humans using natural language. It's not an easy task to process text data efficiently, but it's rewarding! 
For example, when you see systems like Siri, Alexa, or Google Translate working, you're witnessing the power of NLP in action.
"""

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# Initialize stopwords, lemmatizer, and stemmer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

def preprocess_text(text):
    # Step 1: Lowercase the text
    text = text.lower()
    
    # Step 2: Remove numbers and special characters (excluding spaces)
    text = re.sub(r'[^a-z\s]', '', text)
    
    # Step 3: Tokenize the text
    tokens = word_tokenize(text)
    
    # Step 4: Remove stopwords
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    # Step 5: Lemmatize tokens
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    
    # Step 6: Apply stemming (optional)
    stemmed_tokens = [stemmer.stem(word) for word in lemmatized_tokens]
    
    # Return the processed tokens as a string
    return ' '.join(stemmed_tokens)

# Sample text for testing
sample_text = "NLTK is a leading platform for building Python programs to work with human language data."

# Apply preprocessing on sample text
processed_text = preprocess_text(sample_text)
print("Original Text:\n", sample_text)
print("\nPreprocessed Text:\n", processed_text)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\meets\AppData\Local\
# [nltk_data]     Programs\Python\Python312\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\meets\AppData\Lo
# [nltk_data]     cal\Programs\Python\Python312\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[5], line 42
#      39 sample_text = "NLTK is a leading platform for building Python programs to work with human language data."
#      41 # Apply preprocessing on sample text
# ---> 42 processed_text = preprocess_text(sample_text)
#      43 print("Original Text:\n", sample_text)
#      44 print("\nPreprocessed Text:\n", processed_text)
#
# Cell In[5], line 24, in preprocess_text(text)
#      21 text = re.sub(r'[^a-z\s]', '', text)
# ...
